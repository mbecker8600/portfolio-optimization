# %%
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt

# %%
vg_funds = pd.read_csv('data/fund_list.csv')
# Out:
#    fund_name                   asset_class
# 0        EDF   Bond - Long Term Government
# 1        BIV  Bond - Inter Term Government
# 2       VGIT  Bond - Inter Term Investment
# 3        BLV                           NaN
# 4       VGLT                           NaN
# 5       VMBS                           NaN
# 6        BSV                           NaN
# 7       VTIP                           NaN
# 8       VGSH                           NaN
# 9        BND                           NaN
# 10      VCIT                           NaN
# 11      VCLT                           NaN
# 12      VCSH                           NaN
# 13       VTC                           NaN
# 14      VTEB                           NaN
# 15       VIG                           NaN
# 16       VUG                           NaN
# 17       VYM                           NaN
# 18        VV                           NaN
# 19       MGC                           NaN
# 20       MGK                           NaN
# 21       MGV                           NaN
# 22       VOO                           NaN
# 23       VTI                           NaN
# 24       VTV                           NaN
# 25       VXF                           NaN
# 26        VO                           NaN
# 27       VOT                           NaN
# 28       VOE                           NaN
# 29        VB                           NaN
# 30       VBK                           NaN
# 31       VBR                           NaN
# 32      BNDX                           NaN
# 33      VWOB                           NaN
# 34        VT                           NaN
# 35       VEU                           NaN
# 36       VSS                           NaN
# 37       VEA                           NaN
# 38       VGK                           NaN
# 39       VPL                           NaN
# 40      VNQI                           NaN
# 41      VIGI                           NaN
# 42      VYMI                           NaN
# 43      VXUS                           NaN
# 44       VWO                           NaN
# 45       VOX                           NaN
# 46       VCR                           NaN
# 47       VDC                           NaN
# 48       VDE                           NaN
# 49       VFH                           NaN
# 50       VHT                           NaN
# 51       VIS                           NaN
# 52       VGT                           NaN
# 53       VAW                           NaN
# 54       VNQ                           NaN
# 55       VPU                           NaN

# %%
import quandl
quandl.ApiConfig.api_key = 'rb8eEU4go9wAPCe7Woq8'

def get_data(symbols, date_range):
    """Read stock data (adjusted close) for given symbols from Quandl data."""
    
    dfs = []

    pbar = tqdm(total=len(date_range))
    for date in date_range:
        df = quandl.get_table('SHARADAR/SFP', date=date, ticker=symbols)
        dfs.append(df)
        pbar.update(1)
    
    pbar.close()
    data = pd.concat(dfs)
    data = data.reset_index().set_index(['ticker', 'date'])
    return data

# %%
import datetime

start_date = datetime.datetime(2012, 1, 1)
end_date = datetime.datetime(2018, 1, 1)
dates = pd.date_range(start_date, end_date)
symbols = list(vg_funds['fund_name'])

fund_prices = get_data(symbols, dates)
fund_prices.drop(['None', 'lastupdated', 'dividends', 'closeunadj'], axis=1, inplace=True)

# %%
print(len(fund_prices))
# Out:
# 79113

# %%
print(fund_prices.head())
# Out:
#                     open    high    low  close     volume
# ticker date
# BIV    2012-01-03  86.62  87.007  86.62  86.90   379600.0
# BLV    2012-01-03  91.24  91.850  90.88  91.51   171000.0
# BND    2012-01-03  83.43  83.430  83.18  83.28  2282600.0
# BSV    2012-01-03  80.93  80.930  80.75  80.84   786300.0
# EDF    2012-01-03  21.28  21.630  21.21  21.63    69000.0

# %%
sample = fund_prices.sample(n=1).iloc[0]

pre = fund_prices.loc[sample.name[0]].loc[:sample.name[1]]
pre = pre.reset_index().iloc[-lookback-1:]
pre = pre.drop(['date'], axis=1)
pre = pre.pct_change()
pre.dropna(inplace=True)

pre
# Out:
#          open      high       low     close    volume
# 970 -0.009581 -0.004476  0.000537  0.001572 -0.188654
# 971  0.006940  0.001255  0.002095 -0.003872 -0.301642
# 972 -0.011174 -0.008668 -0.013550 -0.013550  1.239675
# 973 -0.010561 -0.011798 -0.011394 -0.010755  0.417847
# 974 -0.010247  0.004797 -0.001185  0.014316 -0.372913

# %%
from sklearn import preprocessing

def create_dataset(fund_prices, 
                   n_samples=10000, 
                   lookback=60, 
                   window=30):
    
    samples = fund_prices.sample(n=n_samples)
    
    X = []
    y = []
    
    
    pbar = tqdm(total=len(samples))
    for index, row in samples.iterrows():
        
        pre = fund_prices.loc[index[0]].loc[:index[1]]
        pre = pre.reset_index().iloc[-lookback:]
        post = fund_prices.loc[index[0]].loc[index[1]:]
        post = post.reset_index().iloc[1:window+1]
        
        pre = pre.drop(['date'], axis=1)
#         pre = pd.DataFrame(scaler.fit_transform(pre), 
#                                   index=pre.index, 
#                                   columns=pre.columns)
        pre = pre.values

        post = post.drop(['date'], axis=1)
#         post = pd.DataFrame(scaler.transform(post), 
#                                   index=post.index, 
#                                   columns=post.columns)
        post = post['close'].values
        
        if len(pre) == lookback and len(post) == window:
            X.append(pre)
            y.append(post)
        
        pbar.update(1)
    
    pbar.close()
    return np.array(X), np.array(y)

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler()
fund_prices_scaled = pd.DataFrame(scaler.fit_transform(fund_prices), 
                                  index=fund_prices.index, 
                                  columns=fund_prices.columns)

# %%
X_train, y_train = create_dataset(fund_prices_scaled, n_samples=70000, window=15)
# Out:
# HBox(children=(IntProgress(value=0, max=70000), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-422-edb1e625cc1a> in <module>()
# ----> 1 X_train, y_train = create_dataset(fund_prices_scaled, n_samples=70000, window=15)
#
# <ipython-input-412-875492dbbde7> in create_dataset(fund_prices, n_samples, lookback, window)
#      38         pbar.update(1)
#      39
# ---> 40     pbar.close()
#      41     return np.array(X), np.array(y)
#
# ~/anaconda/envs/deeplearning_finance/lib/python3.5/site-packages/tqdm/_tqdm_notebook.py in close(self, *args, **kwargs)
#     217
#     218     def close(self, *args, **kwargs):
# --> 219         super(tqdm_notebook, self).close(*args, **kwargs)
#     220         # If it was not run in a notebook, sp is not assigned, check for it
#     221         if hasattr(self, 'sp'):
#
# ~/anaconda/envs/deeplearning_finance/lib/python3.5/site-packages/tqdm/_tqdm.py in close(self)
#    1085         # decrement instance pos and remove from internal set
#    1086         pos = abs(self.pos)
# -> 1087         self._decr_instances(self)
#    1088
#    1089         # GUI mode
#
# ~/anaconda/envs/deeplearning_finance/lib/python3.5/site-packages/tqdm/_tqdm.py in _decr_instances(cls, instance)
#     450         if not cls._instances and cls.monitor:
#     451             try:
# --> 452                 cls.monitor.exit()
#     453                 del cls.monitor
#     454             except AttributeError:  # pragma: nocover
#
# ~/anaconda/envs/deeplearning_finance/lib/python3.5/site-packages/tqdm/_monitor.py in exit(self)
#      48     def exit(self):
#      49         self.was_killed.set()
# ---> 50         self.join()
#      51         return self.report()
#      52
#
# ~/anaconda/envs/deeplearning_finance/lib/python3.5/threading.py in join(self, timeout)
#    1052
#    1053         if timeout is None:
# -> 1054             self._wait_for_tstate_lock()
#    1055         else:
#    1056             # the behavior of a negative timeout isn't documented, but
#
# ~/anaconda/envs/deeplearning_finance/lib/python3.5/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1068         if lock is None:  # already determined that the C code is done
#    1069             assert self._is_stopped
# -> 1070         elif lock.acquire(block, timeout):
#    1071             lock.release()
#    1072             self._stop()
#
# KeyboardInterrupt:

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (951, 60, 5)
# (951, 15)

# %%
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential

def build_model(X, y):
    model = Sequential()
    model.add(LSTM(input_shape=(X.shape[1], X.shape[2]), output_dim=X.shape[1], return_sequences = True))
    model.add(Dropout(0.5))
    model.add(LSTM(256))
    model.add(Dropout(0.5))
    model.add(Dense(y.shape[1]))
    model.add(Activation("linear"))
    model.compile(loss="mse", optimizer="adam")
    model.summary()
    return model

# %%
model = build_model(X=X_train, y=y_train)
# Out:
# /Users/michaelbecker/anaconda/envs/deeplearning_finance/lib/python3.5/site-packages/ipykernel_launcher.py:7: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(return_sequences=True, input_shape=(60, 5), units=60)`
#   import sys
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 60, 60)            15840
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 60, 60)            0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 256)               324608
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 15)                3855
# _________________________________________________________________
# activation_5 (Activation)    (None, 15)                0
# =================================================================
# Total params: 344,303
# Trainable params: 344,303
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, batch_size=64, shuffle=True, epochs=5)

# %% [markdown]
# Evaluate model

# %%
predictions = model.predict(X_train[:20])

# %%
example = 0

real = np.concatenate((X_train[example, :, 3], y_train[example]))
predicted =  np.empty((len(real)))
predicted[:] = np.nan
predicted[60:] = predictions[example]

df = pd.DataFrame(np.vstack((real, predicted)).T)
df.plot()
plt.show()

# %%
start_date = datetime.datetime(2018, 1, 1)
end_date = datetime.datetime(2018, 6, 1)
dates = pd.date_range(start_date, end_date)
symbols = list(vg_funds['fund_name'])

fund_prices_test = get_data(symbols, dates)
fund_prices_test.drop(['None', 'lastupdated', 'dividends', 'closeunadj'], axis=1, inplace=True)

fund_prices_test_scaled = pd.DataFrame(scaler.transform(fund_prices_test), 
                                       index=fund_prices_test.index, 
                                       columns=fund_prices_test.columns)
# Out:
# 100%|██████████| 152/152 [00:43<00:00,  3.95it/s]

# %%
X_test, y_test = create_dataset(fund_prices_test_scaled, n_samples=5000)
# Out:
# 100%|██████████| 5000/5000 [00:18<00:00, 274.29it/s]
